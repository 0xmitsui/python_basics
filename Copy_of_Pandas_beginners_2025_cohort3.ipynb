# %% [markdown]
# <a href="https://colab.research.google.com/github/0xmitsui/python_basics/blob/main/Copy_of_Pandas_beginners_2025_cohort3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing the pandas library
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# Datafrane: This is a pandas method for creating table

data= {"Name": ["David", "Queen", "Peace", "Williams", "Washington", "Teslim", "Sharon", "Faith", "Charles", "Laura"],


      "State": ["Kwara", "Akwa Ibom", "Enugu", "Kogi", "Ogun", "Oyo", "Abuja", "Nasarawa", "Abuja", "Abi"],

       "Course": ["Computer Science", "Computer Engineering", "Computer Engineering", "Software Engineer", "Computer Engineering", "Computer Science", "Data Science", "AI", "Machine Learning", "Mathematics"],


       "School": ["Nile University", "Afebabalola University", "University of Nigeria", "Veritas", "Hill-Side University", "Nile", "University of Abuja", "University of Abuja", "University of Abuja", "University of Abuja"]


}

# %%
df = pd.DataFrame(data)
df
# Out:
#          Name      State                Course                  School
# 0       David      Kwara      Computer Science         Nile University
# 1       Queen  Akwa Ibom  Computer Engineering  Afebabalola University
# 2       Peace      Enugu  Computer Engineering   University of Nigeria
# 3    Williams       Kogi     Software Engineer                 Veritas
# 4  Washington       Ogun  Computer Engineering    Hill-Side University
# 5      Teslim        Oyo      Computer Science                    Nile
# 6      Sharon      Abuja          Data Science     University of Abuja
# 7       Faith   Nasarawa                    AI     University of Abuja
# 8     Charles      Abuja      Machine Learning     University of Abuja
# 9       Laura        Abi           Mathematics     University of Abuja

# %% [markdown]
# **GETTING DATA FROM EXTERNAL SOURCES**

# %%
# loading or reading the dataset from my local machine
election_df = pd.read_csv("/content/HoC-GE2024-results-by-candidate.csv")

# %%
# after loading the dataset, we have to view it
election_df
# Out:
#          ONS ID ONS region ID Constituency name  County name  \
# 0     W07000081     W92000004  Aberafan Maesteg          NaN
# 1     W07000081     W92000004  Aberafan Maesteg          NaN
# 2     W07000081     W92000004  Aberafan Maesteg          NaN
# 3     W07000081     W92000004  Aberafan Maesteg          NaN
# 4     W07000081     W92000004  Aberafan Maesteg          NaN
# ...         ...           ...               ...          ...
# 4510  E14001605     E12000003        York Outer          NaN
# 4511  E14001605     E12000003        York Outer          NaN
# 4512  E14001605     E12000003        York Outer          NaN
# 4513  E14001605     E12000003        York Outer          NaN
# 4514  E14001605     E12000003        York Outer          NaN
#
#                    Region name Country name Constituency type  \
# 0                        Wales        Wales            County
# 1                        Wales        Wales            County
# ...

# %%
# using for loop to retrieve the names of all the variables in the dataset
for col in election_df.columns:
  print(col)
# Out:
# ONS ID
# ONS region ID
# Constituency name
# County name
# Region name
# Country name
# Constituency type
# Party name
# Party abbreviation
# Electoral Commission party ID
# MNIS party ID
# Electoral Commission adjunct party ID
# Candidate first name
# Candidate surname
# Candidate gender
# Sitting MP
# Former MP
# Member MNIS ID
# Votes
# Share
# Change
# DC Person ID

# %%
# using another method from pandas to view the variables name
election_df.columns
# Out:
# Index(['ONS ID', 'ONS region ID', 'Constituency name', 'County name',
#        'Region name', 'Country name', 'Constituency type', 'Party name',
#        'Party abbreviation', 'Electoral Commission party ID', 'MNIS party ID',
#        'Electoral Commission adjunct party ID', 'Candidate first name',
#        'Candidate surname', 'Candidate gender', 'Sitting MP', 'Former MP',
#        'Member MNIS ID', 'Votes', 'Share', 'Change', 'DC Person ID'],
#       dtype='object')

# %%
election_df.head()
# Out:
#       ONS ID ONS region ID Constituency name  County name Region name  \
# 0  W07000081     W92000004  Aberafan Maesteg          NaN       Wales
# 1  W07000081     W92000004  Aberafan Maesteg          NaN       Wales
# 2  W07000081     W92000004  Aberafan Maesteg          NaN       Wales
# 3  W07000081     W92000004  Aberafan Maesteg          NaN       Wales
# 4  W07000081     W92000004  Aberafan Maesteg          NaN       Wales
#
#   Country name Constituency type        Party name Party abbreviation  \
# 0        Wales            County    Heritage Party               HPUK
# 1        Wales            County       Independent                Ind
# 2        Wales            County  Liberal Democrat                 LD
# 3        Wales            County             Green              Green
# 4        Wales            County      Conservative                Con
#
#   Electoral Commission party ID  ...  Candidate first name Candidate surname  \
# ...

# %%
election_df.head(30)
# Out:
#        ONS ID ONS region ID                   Constituency name  County name  \
# 0   W07000081     W92000004                    Aberafan Maesteg          NaN
# 1   W07000081     W92000004                    Aberafan Maesteg          NaN
# 2   W07000081     W92000004                    Aberafan Maesteg          NaN
# 3   W07000081     W92000004                    Aberafan Maesteg          NaN
# 4   W07000081     W92000004                    Aberafan Maesteg          NaN
# 5   W07000081     W92000004                    Aberafan Maesteg          NaN
# 6   W07000081     W92000004                    Aberafan Maesteg          NaN
# 7   W07000081     W92000004                    Aberafan Maesteg          NaN
# 8   S14000060     S92000003                      Aberdeen North          NaN
# 9   S14000060     S92000003                      Aberdeen North          NaN
# 10  S14000060     S92000003                      Aberdeen North          NaN
# ...

# %%
election_df.tail()
# Out:
#          ONS ID ONS region ID Constituency name  County name  \
# 4510  E14001605     E12000003        York Outer          NaN
# 4511  E14001605     E12000003        York Outer          NaN
# 4512  E14001605     E12000003        York Outer          NaN
# 4513  E14001605     E12000003        York Outer          NaN
# 4514  E14001605     E12000003        York Outer          NaN
#
#                    Region name Country name Constituency type  \
# 4510  Yorkshire and The Humber      England            County
# 4511  Yorkshire and The Humber      England            County
# 4512  Yorkshire and The Humber      England            County
# 4513  Yorkshire and The Humber      England            County
# 4514  Yorkshire and The Humber      England            County
#
#             Party name Party abbreviation Electoral Commission party ID  ...  \
# 4510             Green              Green                          PP63  ...
# ...

# %%
election_df.tail(10)
# Out:
#          ONS ID ONS region ID Constituency name  County name  \
# 4505  E14001604     E12000003      York Central          NaN
# 4506  E14001605     E12000003        York Outer          NaN
# 4507  E14001605     E12000003        York Outer          NaN
# 4508  E14001605     E12000003        York Outer          NaN
# 4509  E14001605     E12000003        York Outer          NaN
# 4510  E14001605     E12000003        York Outer          NaN
# 4511  E14001605     E12000003        York Outer          NaN
# 4512  E14001605     E12000003        York Outer          NaN
# 4513  E14001605     E12000003        York Outer          NaN
# 4514  E14001605     E12000003        York Outer          NaN
#
#                    Region name Country name Constituency type  \
# 4505  Yorkshire and The Humber      England           Borough
# 4506  Yorkshire and The Humber      England            County
# 4507  Yorkshire and The Humber      England            County
# ...

# %%
df_sample= election_df.head(100)
df_sample
# Out:
#        ONS ID ONS region ID        Constituency name  County name Region name  \
# 0   W07000081     W92000004         Aberafan Maesteg          NaN       Wales
# 1   W07000081     W92000004         Aberafan Maesteg          NaN       Wales
# 2   W07000081     W92000004         Aberafan Maesteg          NaN       Wales
# 3   W07000081     W92000004         Aberafan Maesteg          NaN       Wales
# 4   W07000081     W92000004         Aberafan Maesteg          NaN       Wales
# ..        ...           ...                      ...          ...         ...
# 95  E14001067     E12000008  Arundel and South Downs          NaN  South East
# 96  E14001067     E12000008  Arundel and South Downs          NaN  South East
# 97  E14001067     E12000008  Arundel and South Downs          NaN  South East
# 98  E14001067     E12000008  Arundel and South Downs          NaN  South East
# 99  E14001067     E12000008  Arundel and South Downs          NaN  South East
#
# ...

# %%
df_sample.head(71).tail(21)
# Out:
#        ONS ID ONS region ID         Constituency name  County name  \
# 50  S14000064     S92000003     Alloa and Grangemouth          NaN
# 51  S14000064     S92000003     Alloa and Grangemouth          NaN
# 52  S14000064     S92000003     Alloa and Grangemouth          NaN
# 53  S14000064     S92000003     Alloa and Grangemouth          NaN
# 54  S14000064     S92000003     Alloa and Grangemouth          NaN
# 55  S14000064     S92000003     Alloa and Grangemouth          NaN
# 56  S14000064     S92000003     Alloa and Grangemouth          NaN
# 57  E14001065     E12000002  Altrincham and Sale West          NaN
# 58  E14001065     E12000002  Altrincham and Sale West          NaN
# 59  E14001065     E12000002  Altrincham and Sale West          NaN
# 60  E14001065     E12000002  Altrincham and Sale West          NaN
# 61  E14001065     E12000002  Altrincham and Sale West          NaN
# 62  E14001065     E12000002  Altrincham and Sale West          NaN
# ...

# %%
# rename method: This is a pandas method for renaming pandas variables

election_df.rename(columns={"Candidate Name": "Candidate_Name"})
# Out:
#          ONS ID ONS region ID Constituency name  County name  \
# 0     W07000081     W92000004  Aberafan Maesteg          NaN
# 1     W07000081     W92000004  Aberafan Maesteg          NaN
# 2     W07000081     W92000004  Aberafan Maesteg          NaN
# 3     W07000081     W92000004  Aberafan Maesteg          NaN
# 4     W07000081     W92000004  Aberafan Maesteg          NaN
# ...         ...           ...               ...          ...
# 4510  E14001605     E12000003        York Outer          NaN
# 4511  E14001605     E12000003        York Outer          NaN
# 4512  E14001605     E12000003        York Outer          NaN
# 4513  E14001605     E12000003        York Outer          NaN
# 4514  E14001605     E12000003        York Outer          NaN
#
#                    Region name Country name Constituency type  \
# 0                        Wales        Wales            County
# 1                        Wales        Wales            County
# ...

# %% [markdown]
# Assignment
#
# 1. Learning everything about pandas rename method
#
# 2. Learn loc[] and iloc[] pandas methods
#
# 3. Learn pandas replace method
#
# 4. Learn pandas fillna()
#
# 5. Learn pandas conditional filtering techniques

# %% [markdown]
# **MODULE 2: TASKS TO BE DONE**
#
# **A. Handling Missing Data**
#
# 1. df.isnull() – Detect missing values.
#
# 2. df.notnull() – Detect non-missing values.
#
# 3. df.dropna() – Remove missing values.
#
# 4. df.fillna(value) – Replace missing values with a given value.
#
#
# **B. Data Selection & Filtering**
#
#
# 1. df.loc[] – Select rows/columns by labels.
#
# 2. df.iloc[] – Select rows/columns by integer positions.
#
# 3. df.query() – Filter rows using query strings.
#
#
# **C. Data Transformation**
#
# df.rename(columns={}) – Rename columns.
#
# df.astype() – Change column data types.
#
# df.map() – Apply function to Series elements.
#
# df.replace() – Replace values with others.
#
#
# **D. Aggregation & Grouping**
#
# 1. df.groupby() – Group data and apply aggregation.
#
# 2. df.value_counts()
#
# 3. df.unique (): This returns the number of uni
#
# 4. df,nunique ()
#
#
# F. Core Conditional Filtering
#
# 1. Boolean Indexing – df[df['col'] > 10] → Select rows where column > 10.
#
# 2. Multiple Conditions – df[(df['col1'] > 10) & (df['col2'] < 50)] → Combine with &, |, ~.
#
# 3. df.query() – df.query("col1 > 10 and col2 < 50")
#
#
#
#   Value-based Filtering
#
#
# 4. df['col'].isin([x,y,z]) – Select rows where values are in a list.
#
# 5. df['col'].between(a, b) – Select rows where values fall between a and b.
#
# 6. df['col'].duplicated() – Filter duplicated rows.
#
# 7. df.nunique() with conditions – Identify unique counts for filtering.
#
#       Null & Missing Data Filters
#
# 8. df[df['col'].isnull()] – Rows with missing values.
#
# 9. df[df['col'].notnull()] – Rows without missing values.

# %%
election_df
# Out:
#          ONS ID ONS region ID Constituency name  County name  \
# 0     W07000081     W92000004  Aberafan Maesteg          NaN
# 1     W07000081     W92000004  Aberafan Maesteg          NaN
# 2     W07000081     W92000004  Aberafan Maesteg          NaN
# 3     W07000081     W92000004  Aberafan Maesteg          NaN
# 4     W07000081     W92000004  Aberafan Maesteg          NaN
# ...         ...           ...               ...          ...
# 4510  E14001605     E12000003        York Outer          NaN
# 4511  E14001605     E12000003        York Outer          NaN
# 4512  E14001605     E12000003        York Outer          NaN
# 4513  E14001605     E12000003        York Outer          NaN
# 4514  E14001605     E12000003        York Outer          NaN
#
#                    Region name Country name Constituency type  \
# 0                        Wales        Wales            County
# 1                        Wales        Wales            County
# ...

# %%
# checking for missing values (entries) in the dataset

election_df.isnull()
# Out:
#       ONS ID  ONS region ID  Constituency name  County name  Region name  \
# 0      False          False              False         True        False
# 1      False          False              False         True        False
# 2      False          False              False         True        False
# 3      False          False              False         True        False
# 4      False          False              False         True        False
# ...      ...            ...                ...          ...          ...
# 4510   False          False              False         True        False
# 4511   False          False              False         True        False
# 4512   False          False              False         True        False
# 4513   False          False              False         True        False
# 4514   False          False              False         True        False
#
#       Country name  Constituency type  Party name  Party abbreviation  \
# ...

# %%
# an alternative way of checking for missing entries in a dataset
election_df.isna()
# Out:
#       ONS ID  ONS region ID  Constituency name  County name  Region name  \
# 0      False          False              False         True        False
# 1      False          False              False         True        False
# 2      False          False              False         True        False
# 3      False          False              False         True        False
# 4      False          False              False         True        False
# ...      ...            ...                ...          ...          ...
# 4510   False          False              False         True        False
# 4511   False          False              False         True        False
# 4512   False          False              False         True        False
# 4513   False          False              False         True        False
# 4514   False          False              False         True        False
#
#       Country name  Constituency type  Party name  Party abbreviation  \
# ...

# %%
#  checking the sum of missin entries by variables
election_df.isna().sum()
# Out:
# ONS ID                                      0
# ONS region ID                               8
# Constituency name                           0
# County name                              4515
# Region name                                 0
# Country name                                0
# Constituency type                           0
# Party name                                  0
# Party abbreviation                          0
# Electoral Commission party ID             460
# MNIS party ID                               0
# Electoral Commission adjunct party ID    4466
# Candidate first name                        0
# Candidate surname                           0
# Candidate gender                            0
# Sitting MP                                  0
# Former MP                                   0
# Member MNIS ID                           3630
# Votes                                       0
# Share                                       0
# ...

# %%
# checking the sum of missin values in the entire dataset
election_df.isna().sum().sum()
# Out:
# np.int64(14585)

# %%
# filter all the instances (rows) in the dataset with any missin value

election_df.notnull().sum().sum()
# Out:
# np.int64(84745)

# %%
#

#without_missing_valuse= election_df.dropna()

# %%
election_df.drop('County name', axis=1, inplace=True)

# %%
election_df.isnull().sum().sum()
# Out:
# np.int64(10070)

# %%
election_df.isnull().sum()
# Out:
# ONS ID                                      0
# ONS region ID                               8
# Constituency name                           0
# Region name                                 0
# Country name                                0
# Constituency type                           0
# Party name                                  0
# Party abbreviation                          0
# Electoral Commission party ID             460
# MNIS party ID                               0
# Electoral Commission adjunct party ID    4466
# Candidate first name                        0
# Candidate surname                           0
# Candidate gender                            0
# Sitting MP                                  0
# Former MP                                   0
# Member MNIS ID                           3630
# Votes                                       0
# Share                                       0
# Change                                   1506
# ...

# %%
# inspecting the  Electoral Commission adjunct party ID to know the distinct values in the variable
election_df['Electoral Commission adjunct party ID'].value_counts()
# Out:
# Electoral Commission adjunct party ID
# PP119    49
# Name: count, dtype: int64

# %%
election_df['Electoral Commission adjunct party ID'].fillna(value=0, inplace=True)

# %%
election_df['Electoral Commission adjunct party ID'].value_counts()
# Out:
# Electoral Commission adjunct party ID
# 0        4466
# PP119      49
# Name: count, dtype: int64

# %%
election_df[['ONS ID', 'Electoral Commission adjunct party ID']]
# Out:
#          ONS ID Electoral Commission adjunct party ID
# 0     W07000081                                     0
# 1     W07000081                                     0
# 2     W07000081                                     0
# 3     W07000081                                     0
# 4     W07000081                                     0
# ...         ...                                   ...
# 4510  E14001605                                     0
# 4511  E14001605                                     0
# 4512  E14001605                                     0
# 4513  E14001605                                     0
# 4514  E14001605                                     0
#
# [4515 rows x 2 columns]

# %%
election_df.isnull().sum()
# Out:
# ONS ID                                      0
# ONS region ID                               8
# Constituency name                           0
# Region name                                 0
# Country name                                0
# Constituency type                           0
# Party name                                  0
# Party abbreviation                          0
# Electoral Commission party ID             460
# MNIS party ID                               0
# Electoral Commission adjunct party ID       0
# Candidate first name                        0
# Candidate surname                           0
# Candidate gender                            0
# Sitting MP                                  0
# Former MP                                   0
# Member MNIS ID                           3630
# Votes                                       0
# Share                                       0
# Change                                   1506
# ...

# %%
election_df[['Electoral Commission party ID', 'Member MNIS ID', 'Change']].fillna(value=0, inplace=True)

# %%
election_df.isnull().sum()
# Out:
# ONS ID                                      0
# ONS region ID                               8
# Constituency name                           0
# Region name                                 0
# Country name                                0
# Constituency type                           0
# Party name                                  0
# Party abbreviation                          0
# Electoral Commission party ID             460
# MNIS party ID                               0
# Electoral Commission adjunct party ID       0
# Candidate first name                        0
# Candidate surname                           0
# Candidate gender                            0
# Sitting MP                                  0
# Former MP                                   0
# Member MNIS ID                           3630
# Votes                                       0
# Share                                       0
# Change                                   1506
# ...

# %%
# filling up three variables where there were missing values using a fix value (0)
election_df['Electoral Commission party ID'].fillna(value=0, inplace=True)
election_df['Member MNIS ID'].fillna(value=0, inplace=True)
election_df['Change'].fillna(value=0, inplace=True)

# %%
election_df.isnull().sum()
# Out:
# ONS ID                                   0
# ONS region ID                            8
# Constituency name                        0
# Region name                              0
# Country name                             0
# Constituency type                        0
# Party name                               0
# Party abbreviation                       0
# Electoral Commission party ID            0
# MNIS party ID                            0
# Electoral Commission adjunct party ID    0
# Candidate first name                     0
# Candidate surname                        0
# Candidate gender                         0
# Sitting MP                               0
# Former MP                                0
# Member MNIS ID                           0
# Votes                                    0
# Share                                    0
# Change                                   0
# DC Person ID                             0
# dtype: int64

# %%
# viewing the dataset
election_df
# Out:
#          ONS ID ONS region ID Constituency name               Region name  \
# 0     W07000081     W92000004  Aberafan Maesteg                     Wales
# 1     W07000081     W92000004  Aberafan Maesteg                     Wales
# 2     W07000081     W92000004  Aberafan Maesteg                     Wales
# 3     W07000081     W92000004  Aberafan Maesteg                     Wales
# 4     W07000081     W92000004  Aberafan Maesteg                     Wales
# ...         ...           ...               ...                       ...
# 4510  E14001605     E12000003        York Outer  Yorkshire and The Humber
# 4511  E14001605     E12000003        York Outer  Yorkshire and The Humber
# 4512  E14001605     E12000003        York Outer  Yorkshire and The Humber
# 4513  E14001605     E12000003        York Outer  Yorkshire and The Humber
# 4514  E14001605     E12000003        York Outer  Yorkshire and The Humber
#
#      Country name Constituency type        Party name Party abbreviation  \
# ...

# %% [markdown]
# **SELECTING SPECIFIC COLUMNS USING PANDAS**

# %%
# selecting a single variable using pandas

# Univariate: A univariate is a kind of findings that is carried out on a single varraible
election_df['Party name']
# Out:
# 0         Heritage Party
# 1            Independent
# 2       Liberal Democrat
# 3                  Green
# 4           Conservative
#               ...
# 4510               Green
# 4511    Liberal Democrat
# 4512           Reform UK
# 4513        Conservative
# 4514              Labour
# Name: Party name, Length: 4515, dtype: object

# %%
election_df['Party name'].unique()
# Out:
# array(['Heritage Party', 'Independent', 'Liberal Democrat', 'Green',
#        'Conservative', 'Plaid Cymru', 'Reform UK', 'Labour',
#        'Trade Unionist and Socialist Coalition', 'Scottish Family Party',
#        'Alba Party', 'Scottish Green Party', 'Scottish National Party',
#        'British Unionist Party B.U.P.', 'Hampshire Independents',
#        'Workers Party of Britain', 'Sovereignty',
#        'Social Democratic Party', 'Ashfield Independents', 'Consensus',
#        'Climate Party', 'Socialist Labour Party',
#        'Christian Peoples Alliance Party', 'English Democrats',
#        'The Yorkshire Party', 'Party of Women',
#        'British Democratic Party', 'Independence for Scotland Party',
#        'Labour and Co-operative', 'Rejoin EU',
#        'Social Democratic and Labour Party', 'Ulster Unionist Party',
#        'Traditional Unionist Voice', 'Alliance',
#        'Democratic Unionist Party', 'People Before Profit Alliance',
# ...

# %%
election_df['Party name'].nunique()
# Out:
# 99

# %%
election_df["Party name"].value_counts()
# Out:
# Party name
# Conservative                                   635
# Liberal Democrat                               630
# Reform UK                                      609
# Green                                          585
# Labour                                         582
#                                               ...
# Stockport Fights Austerity No To Cuts            1
# Independents for Direct Democracy                1
# New Open Non-Political Organised Leadership      1
# Independent Alliance (Kent)                      1
# Newham Independents Party                        1
# Name: count, Length: 99, dtype: int64

# %%
# bivariate analysis: This is a process of selecting two variables for analysis

election_df[['Party name', 'Country name']]
# Out:
#             Party name Country name
# 0       Heritage Party        Wales
# 1          Independent        Wales
# 2     Liberal Democrat        Wales
# 3                Green        Wales
# 4         Conservative        Wales
# ...                ...          ...
# 4510             Green      England
# 4511  Liberal Democrat      England
# 4512         Reform UK      England
# 4513      Conservative      England
# 4514            Labour      England
#
# [4515 rows x 2 columns]

# %%
# selecting more than two features from the dataset to perform mutli-variate analysis
election_df[['Party name', 'Country name', 'Constituency type']]
# Out:
#             Party name Country name Constituency type
# 0       Heritage Party        Wales            County
# 1          Independent        Wales            County
# 2     Liberal Democrat        Wales            County
# 3                Green        Wales            County
# 4         Conservative        Wales            County
# ...                ...          ...               ...
# 4510             Green      England            County
# 4511  Liberal Democrat      England            County
# 4512         Reform UK      England            County
# 4513      Conservative      England            County
# 4514            Labour      England            County
#
# [4515 rows x 3 columns]

# %%
election_df.loc[:, ['Party name', 'Country name'] ]
# Out:
#             Party name Country name
# 0       Heritage Party        Wales
# 1          Independent        Wales
# 2     Liberal Democrat        Wales
# 3                Green        Wales
# 4         Conservative        Wales
# ...                ...          ...
# 4510             Green      England
# 4511  Liberal Democrat      England
# 4512         Reform UK      England
# 4513      Conservative      England
# 4514            Labour      England
#
# [4515 rows x 2 columns]

# %%
election_df.iloc[:, [6, 4]]
# Out:
#             Party name Country name
# 0       Heritage Party        Wales
# 1          Independent        Wales
# 2     Liberal Democrat        Wales
# 3                Green        Wales
# 4         Conservative        Wales
# ...                ...          ...
# 4510             Green      England
# 4511  Liberal Democrat      England
# 4512         Reform UK      England
# 4513      Conservative      England
# 4514            Labour      England
#
# [4515 rows x 2 columns]

# %%
# using query method to slect features from our dataset
election_df.query('`Party name` == "Green"')
# Out:
#          ONS ID ONS region ID          Constituency name  \
# 3     W07000081     W92000004           Aberafan Maesteg
# 38    E14001063     E12000008                  Aldershot
# 43    E14001064     E12000005        Aldridge-Brownhills
# 58    E14001065     E12000002   Altrincham and Sale West
# 64    W07000082     W92000004           Alyn and Deeside
# ...         ...           ...                        ...
# 4479  E14001602     E12000002  Wythenshawe and Sale East
# 4484  E14001603     E12000009                     Yeovil
# 4492  W07000112     W92000004                   Ynys Môn
# 4503  E14001604     E12000003               York Central
# 4510  E14001605     E12000003                 York Outer
#
#                    Region name Country name Constituency type Party name  \
# 3                        Wales        Wales            County      Green
# 38                  South East      England           Borough      Green
# ...

# %% [markdown]
# ASSIGNMENT 2:
#
# Using the election dataset, do the following tasks:
#
# 1. df['col'].isin([x,y,z]) – Select rows where values are in a list.
#
# 2. df['col'].between(a, b) – Select rows where values fall between a and b.
#
# 3. df['col'].duplicated() – Filter duplicated rows.
#
# 4. df.nunique() with conditions – Identify unique counts for filtering.
#
#
# submit the assignment to: michaelanietiejack@gmail.com

# %%
election_df
# Out:
#          ONS ID ONS region ID Constituency name               Region name  \
# 0     W07000081     W92000004  Aberafan Maesteg                     Wales
# 1     W07000081     W92000004  Aberafan Maesteg                     Wales
# 2     W07000081     W92000004  Aberafan Maesteg                     Wales
# 3     W07000081     W92000004  Aberafan Maesteg                     Wales
# 4     W07000081     W92000004  Aberafan Maesteg                     Wales
# ...         ...           ...               ...                       ...
# 4510  E14001605     E12000003        York Outer  Yorkshire and The Humber
# 4511  E14001605     E12000003        York Outer  Yorkshire and The Humber
# 4512  E14001605     E12000003        York Outer  Yorkshire and The Humber
# 4513  E14001605     E12000003        York Outer  Yorkshire and The Humber
# 4514  E14001605     E12000003        York Outer  Yorkshire and The Humber
#
#      Country name Constituency type        Party name Party abbreviation  \
# ...

# %%
election_df['Party name'].isin(['Green','Independent','Liberal Democrat'])
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 4510     True
# 4511     True
# 4512    False
# 4513    False
# 4514    False
# Name: Party name, Length: 4515, dtype: bool

# %%
election_df['Votes'].between(1,200)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4510    False
# 4511    False
# 4512    False
# 4513    False
# 4514    False
# Name: Votes, Length: 4515, dtype: bool

# %%
election_df['Votes'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4510    False
# 4511    False
# 4512     True
# 4513    False
# 4514    False
# Name: Votes, Length: 4515, dtype: bool

# %%
election_df['Votes'].duplicated().sum()
# Out:
# np.int64(882)

# %%
election_df['Country name'].nunique()
# election_df.loc[:, election_df.nunique() == 2]
# Out:
# 4

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df.head()


df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.groupby(['Pclass', 'Sex'])['Pclass'].count()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# Name: Pclass, dtype: int64

# %%
sur = df[(df['Survived'] == 1) | (df['Sex'] == "female")]
sur
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
old = df.query("Age >= 50 & Survived == 1")
old
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 195          196         1       1
# 259          260         1       2
# 268          269         1       1
# 275          276         1       1
# 299          300         1       1
# 366          367         1       1
# 449          450         1       1
# 458          459         1       2
# 483          484         1       3
# 496          497         1       1
# 513          514         1       1
# 526          527         1       2
# 570          571         1       2
# 571          572         1       1
# 587          588         1       1
# 591          592         1       1
# 630          631         1       1
# 647          648         1       1
# 660          661         1       1
# 765          766         1       1
# 774          775         1       2
# 820          821         1       1
# 829          830         1       1
# ...

# %%
filt = df.query("SibSp > 0 & Pclass == 3")
filt
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 13            14         0       3               Andersson, Mr. Anders Johan
# 16            17         0       3                      Rice, Master. Eugene
# ..           ...       ...     ...                                       ...
# 852          853         0       3                   Boulos, Miss. Nourelain
# 860          861         0       3                   Hansen, Mr. Claus Peter
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869          870         1       3           Johnson, Master. Harold Theodor
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...
